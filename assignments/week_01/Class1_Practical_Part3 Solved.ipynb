# %% [markdown]
# # Class 1 Practical Notebook - Part 3
#
# **Practicals 21–30**
#
# Complete the following practicals using only the concepts covered in Class 1.

# %% [markdown]
# # Practical 21 - Safe Age Input
#
# ## Problem
#
# A university registration system requires the student's age as a number.
#
# Ask the user to enter their age.
#
# If the user enters an invalid value (such as letters or symbols), display an appropriate error message using `try-except`.
#
# Otherwise display the entered age.
#
# ### Pseudocode
#
# ```
# START
# Try
#     Input age
#     Convert age into integer
#     Display age
# Except
#     Display error message
# END
# ```

# %%
age_str = str(input("Enter age : "))
try:
    age = int(age_str)
    print(age)
except:
  print(f'Invalid age.')
# Out:
# Enter age : @45
# Invalid age.

# %% [markdown]
# # Practical 22 - Safe Temperature Converter
#
# ## Problem
#
# A laboratory technician enters temperature readings throughout the day.
#
# Ask the user to enter the temperature in Celsius.
#
# Convert it into Fahrenheit.
#
# If the user enters invalid data, display an appropriate error message.
#
# ## Formula
#
# $$F=(C\times\frac{9}{5})+32$$
#
# ### Pseudocode
#
# ```
# START
# Try
#     Input Celsius temperature
#     Convert into Fahrenheit
#     Display both temperatures
# Except
#     Display error message
# END
# ```

# %%
# Write your solution here
celcius_str = str(input("Enter tempreture in celcius :"))
try:
  celcius = float(celcius_str)
  fahrenheit = (celcius*9/5)+32
  print(f'Fahrenheit : {fahrenheit}')
except:
  print(f'Invalid value . Enter only float')
# Out:
# Enter tempreture in celcius :42
# Fahrenheit : 107.6

# %% [markdown]
# # Practical 23 - Library Membership Record
#
# ## Problem
#
# A public library has registered a new member.
#
# Collect the following information from the user:
#
# - Member Name
# - Age
# - City
# - Annual Membership Fee
#
# Display all information using formatted printing.
#
# ### Pseudocode
#
# ```
# START
# Input member information
# Store the values
# Display a formatted membership record
# END
# ```

# %%
# Write your solution here
name = str(input("Enter name :"))
age = int(input("Enter age   :"))
city = str(input("Enter city :"))
fee = int(input("Enter fee   :"))
print(f'=' * 42)
print(f'          Library Membership Record')
print(f'='*42)
print(f'Name                  : {name:^15}')
print(f'Age                   : {age:^15}')
print(f'City                  : {city:^15}')
print(f'Annual Membership Fee : {fee:^15}')
print(f'='*42)
# Out:
# Enter name :Faizan Gill
# Enter age :20
# Enter city :Faisalabad
# Enter fee :20000
# ...
#           Library Membership Record
# ...
# Name                  :   Faizan Gill
# Age                   :       20
# City                  :   Faisalabad
# Annual Membership Fee :      20000
# ...

# %% [markdown]
# # Practical 24 - Electricity Bill Calculator
#
# ## Problem
#
# An electricity company charges customers based on the number of units consumed.
#
# Ask the user to enter:
#
# - Units Consumed
# - Cost per Unit
#
# Display:
# - Total Electricity Bill
#
# ## Formula
#
# $$\mathrm{Bill}=\mathrm{Units}\times\mathrm{Cost\ Per\ Unit}$$
#
# ### Pseudocode
#
# ```
# START
# Input units consumed
# Input cost per unit
# Calculate bill
# Display total bill
# END
# ```

# %%
# Write your solution here
unit = float(input("Enter no of units :"))
cost = float(input("Enter cost per unit :"))
bill = unit * cost
print(f'Total bill : {bill}')
# Out:
# Enter no of units :200
# Enter cost per unit :45
# Total bill : 9000.0

# %% [markdown]
# # Practical 25 - Body Mass Index (BMI) Calculator
#
# ## Problem
#
# A fitness centre wants to estimate the Body Mass Index (BMI) of its members.
#
# Ask the user to enter:
#
# - Weight (kg)
# - Height (m)
#
# Display:
# - BMI
#
# ## Formula
#
# $$BMI=\frac{Weight(kg)}{Height(m)^2}$$
#
# ### Pseudocode
#
# ```
# START
# Input weight
# Input height
# Calculate BMI
# Display BMI
# END
# ```

# %%
# Write your solution here
weight = float(input("Enter weight :"))
height = float(input("Enter height :"))
bmi = weight / (height**2)
print(f'BMI : {bmi}')
# Out:
# Enter weight :85
# Enter height :1.55
# BMI : 35.37981269510926

# %% [markdown]
# # Practical 26 - Restaurant Bill Calculator
#
# ## Problem
#
# A restaurant receives the following order:
#
# | Item | Quantity | Price (PKR) |
# |---|---:|---:|
# | Burger | 2 | 650 |
# | Fries | 1 | 350 |
# | Soft Drink | 2 | 180 |
#
# Store the given values.
#
# Calculate and display:
# - Total Bill
#
# ## Formula
#
# $$\mathrm{Total}=\sum (Quantity\times Price)$$
#
# ### Pseudocode
#
# ```
# START
# Store quantities and prices
# Calculate total cost of each item
# Calculate final bill
# Display total bill
# END
# ```

# %%
# Write your solution here
burger = 2 * 650
fries = 1 * 350
soft_drink = 2 * 180
total = burger + fries + soft_drink
print(f'Total bill : {total}')
# Out:
# Total bill : 2010

# %% [markdown]
# # Practical 27 - Rainfall Summary
#
# ## Problem
#
# A weather department recorded rainfall for three cities.
#
# | City | Rainfall (mm) |
# |---|---:|
# | Islamabad | 42 |
# | Lahore | 18 |
# | Karachi | 5 |
#
# Store the rainfall values.
#
# Display:
# - Total Rainfall
# - Average Rainfall
#
# ## Formula
#
# $$\mathrm{Average}=\frac{R_1+R_2+R_3}{3}$$
#
# ### Pseudocode
#
# ```
# START
# Store rainfall values
# Calculate total rainfall
# Calculate average rainfall
# Display both values
# END
# ```

# %%
# Write your solution here
islamabad = 42
lahore = 18
karachi = 5
total = islamabad + lahore + karachi
average = total / 3
print(f'Total rainfall : {total}')
print(f'Average rainfall : {average:2f}')
# Out:
# Total rainfall : 65
# Average rainfall : 21.666667

# %% [markdown]
# # Practical 28 - Employee Salary Report
#
# ## Problem
#
# A company has recorded the following information:
#
# | Variable | Value |
# |---|---|
# | Employee Name | Fatima Noor |
# | Basic Salary | 85000 |
# | Bonus | 12000 |
#
# Store the information.
#
# Calculate and display:
# - Gross Salary
#
# ## Formula
#
# $$\mathrm{Gross\ Salary}=\mathrm{Basic\ Salary}+\mathrm{Bonus}$$
#
# ### Pseudocode
#
# ```
# START
# Store employee information
# Calculate gross salary
# Display employee report
# END
# ```

# %%
# Write your solution here
name = 'Fatima noor '
salary = 85000
bonus = 12000
total = salary + bonus
print(f'Employee name : {name}')
print(f'Basic salary  : {salary}')
print(f'Bonus         : {bonus}')
print(f'Total salary  : {total}')
# Out:
# Employee name : Fatima noor
# Basic salary  : 85000
# Bonus         : 12000
# Total salary  : 97000

# %% [markdown]
# # Practical 29 - Travel Expense Calculator
#
# ## Problem
#
# A business traveler recorded the following expenses:
#
# | Expense | Amount (PKR) |
# |---|---:|
# | Hotel | 18500 |
# | Food | 6400 |
# | Transport | 3800 |
#
# Store the expenses.
#
# Calculate and display:
# - Total Expense
# - Average Expense
#
# ## Formula
#
# $$\mathrm{Total}=Hotel+Food+Transport$$
#
# $$\mathrm{Average}=\frac{\mathrm{Total}}{3}$$
#
# ### Pseudocode
#
# ```
# START
# Store expenses
# Calculate total
# Calculate average
# Display results
# END
# ```

# %%
# Write your solution here
hotel = 18500
food = 6400
transport = 3800
total = hotel + food + transport
average =  total / 3
print(f'Total expence : {total}')
print(f'Average expence : {average:2f}')
# Out:
# Total expence : 28700
# Average expence : 9566.666667

# %% [markdown]
# # Practical 30 - Mini Data Analytics Report
#
# ## Problem
#
# A company wants to create a simple employee information report.
#
# Ask the user to enter:
#
# - Employee Name
# - Age
# - Department
# - Monthly Salary
#
# Display a professional report showing all information.
#
# Additionally:
#
# - Display the datatype of each value using `type()`.
# - Verify that the salary is numeric using `isinstance()`.
# - If the user enters an invalid age or salary, handle the error using `try-except`.
#
# ### Pseudocode
#
# ```
# START
# Try
#     Input employee information
#     Convert numeric values
#     Display formatted report
#     Display datatype of each value
#     Validate salary datatype
# Except
#     Display error message
# END
# ```

# %%
# Write your solution here
name = str(input("Enter name :"))
age = float(input("Enter age   :"))
depertment = str(input("Enter depertment :"))
salary = float(input("Enter monthly salary :"))
try:
  age_int = int(age)
  salary_int = int(salary)
  print(f'=' * 42)
  print(f'              Data Report ')
  print(f'=' * 42)
  print(f'Name                   : {name:^15}')
  print(f'Age                    : {age_int:^15}')
  print(f'Department             : {depertment:^15}')
  print(f'Monthly Salary         : {salary_int:^15}')
  print(f'Type name              : {type(name).__name__:^15}')
  print(f'Type age               : {type(age_int).__name__:^15}')
  print(f'Type depertment        : {type(depertment).__name__:^15}')
  print(f'Type salary            : {type(salary_int).__name__:^15}')
  print(f'Salary in numeric form : {isinstance(salary,int):^15}')
  print(f'=' * 42)
except:
  print(f'Invalid data type')
# Out:
# Enter name :Faizan Gill
# Enter age   :20
# Enter depertment :Data Science
# Enter monthly salary :180000
# ...
#               Data Report
# ...
# Name                   :   Faizan Gill
# Age                    :       20
# Department             :  Data Science
# Monthly Salary         :     180000
# Type name              :       str
# Type age               :       int
# Type depertment        :       str
# Type salary            :       int
# Salary in numeric form :        0
# ...
