# %% [markdown]
# # Class 1 Practical Notebook - Part 2
#
# **Practicals 11–20**
#
# Continue solving the following practicals using only the concepts covered in Class 1.

# %% [markdown]
# # Practical 11 - Warehouse Area Calculator
#
# ## Problem
#
# A warehouse manager recorded the following dimensions:
#
# | Measurement | Value |
# |---|---:|
# | Length (m) | User Input |
# | Width (m) | User Input |
#
# Ask the user to enter the length and width.
#
# Display:
# - Length
# - Width
# - Area of the warehouse
#
# ## Formula
#
# $$\mathrm{Area}=\mathrm{Length}\times\mathrm{Width}$$
#
# ### Pseudocode
#
# ```
# START
# Input length
# Input width
# Calculate area
# Display length
# Display width
# Display area
# END
# ```

# %%
# Write your solution here
length = float(input("Enter length : "))
width = float(input("Enter width : "))
area = length*width
print(f'Length : {length}ft')
print(f'Width : {width}ft')
print(f'Area : {area}sqft')
# Out:
# Enter length : 50
# Enter width : 60
# Length : 50.0ft
# Width : 60.0ft
# Area : 3000.0sqft

# %% [markdown]
# # Practical 12 - Patient Weight Converter
#
# ## Problem
#
# A clinic stores patient weight in kilograms, but an overseas partner requires pounds.
#
# Ask the user to enter the patient's weight in kilograms.
#
# Display:
# - Weight in kilograms
# - Weight in pounds (2 decimal places)
#
# ## Formula
#
# $$\mathrm{Pounds}=\mathrm{Kilograms}\times2.20462$$
#
# ### Pseudocode
#
# ```
# START
# Input weight in kilograms
# Convert to pounds
# Display both values
# END
# ```

# %%
# Write your solution here
weight_kg = float(input("Enter wright in kg : "))
weight_lb = weight_kg*2.20462
print(f'Weight in kg : {weight_kg}')
print(f'Weight in lb : {weight_lb}')
# Out:
# Enter wright in kg : 74
# Weight in kg : 74.0
# Weight in lb : 163.14188

# %% [markdown]
# # Practical 13 - Road Distance Converter
#
# ## Problem
#
# A navigation system records distance in kilometres.
#
# Ask the user to enter a distance in kilometres.
#
# Display:
# - Distance in kilometres
# - Distance in miles
#
# ## Formula
#
# $$\mathrm{Miles}=\mathrm{Kilometres}\times0.621371$$
#
# ### Pseudocode
#
# ```
# START
# Input distance in kilometres
# Convert to miles
# Display both values
# END
# ```

# %%
# Write your solution here
distance_km = float(input("Enter distance in km : "))
distance_mile = distance_km*0.621371
print(f'Distance in km : {distance_km}')
print(f'Distance in mile : { distance_mile}')
# Out:
# Enter distance in km : 83
# Distance in km : 83.0
# Distance in mile : 51.573793

# %% [markdown]
# # Practical 14 - Exam Result Comparison
#
# ## Problem
#
# Two students obtained the following marks:
#
# | Student | Marks |
# |---|---:|
# | Ali | 78 |
# | Sara | 91 |
#
# Store the marks.
#
# Display:
# - Whether Ali scored more than Sara
# - Whether Sara scored more than Ali
# - Whether both scored the same marks
#
# ### Pseudocode
#
# ```
# START
# Store both marks
# Compare using >, < and ==
# Display comparison results
# END
# ```

# %%
# Write your solution here
ali_marks = 78
sara_marks = 91
print(f'Ali scored more then Sara : {ali_marks > sara_marks}')
print(f'Sara scored more then Ali : {ali_marks < sara_marks}')
print(f'Both scored the same marks : {ali_marks == sara_marks}')
# Out:
# Ali scored more then Sara : False
# Sara scored more then Ali : True
# Both scored the same marks : False

# %% [markdown]
# # Practical 15 - Scholarship Eligibility Checker
#
# ## Problem
#
# A university awards scholarships if:
#
# - CGPA is **3.50 or above**
# - Attendance is **80% or above**
#
# Ask the user to enter both values.
#
# Display whether the student is eligible using logical operators.
#
# ### Pseudocode
#
# ```
# START
# Input CGPA
# Input attendance
# Check both conditions using AND
# Display eligibility
# END
# ```

# %%
# Write your solution here
cgpa = float (input("Enter CGPA :"))
attendance = float(input("Enter attendance :"))
print(f'Eligibile for scholarship .[{cgpa>3.50 and attendance>80}]')
# Out:
# Enter CGPA :3.0
# Enter attendance :85
# Eligibile for scholarship .[False]

# %% [markdown]
# # Practical 16 - Bank Loan Eligibility
#
# ## Problem
#
# A bank approves a personal loan when:
#
# - Age is at least 21 years
# - Monthly income is at least PKR 50,000
#
# Ask the user to enter both values.
#
# Display whether the applicant is eligible.
#
# ### Pseudocode
#
# ```
# START
# Input age
# Input monthly income
# Check conditions using logical operators
# Display result
# END
# ```

# %%
# Write your solution here
age = int(input("Enter age :"))
monthly_income = float(input("Enter monthly income :  "))
print(f'Eligible for loan [{age>21 and monthly_income>50000}]')
# Out:
# Enter age :25
# Enter monthly income :  56000
# Eligible for loan [True]

# %% [markdown]
# # Practical 17 - Sports Tournament Registration
#
# ## Problem
#
# A participant can register if:
#
# - Age is at least 18 years
# OR
# - The participant has parental permission.
#
# Ask the user to enter the required information.
#
# Display whether registration is allowed.
#
# ### Pseudocode
#
# ```
# START
# Input age
# Input parental permission
# Use OR operator
# Display result
# END
# ```

# %%
# Write your solution here
age = int(input("Enter age :"))
permission = bool(input("Enter permission in (yes/no) :"))
print(f'Registration allowed : [{age>18 or permission}]')
# Out:
# Enter age :18
# Enter permission in (yes/no) :no
# Registration allowed : [True]

# %% [markdown]
# # Practical 18 - Fuel Cost Estimator
#
# ## Problem
#
# A transport company wants to estimate the fuel cost for a delivery.
#
# Ask the user to enter:
#
# - Fuel required (litres)
# - Price per litre
#
# Display:
# - Total fuel cost
#
# ## Formula
#
# $$\mathrm{Cost}=\mathrm{Litres}\times\mathrm{Price\ Per\ Litre}$$
#
# ### Pseudocode
#
# ```
# START
# Input litres
# Input price per litre
# Calculate cost
# Display total cost
# END
# ```

# %%
# Write your solution here
liter = float(input("Enter fuel litter : "))
price = float(input("Enter price per litter : "))
total_cost = liter*price
print(f'Total fuel cost = {total_cost}')
# Out:
# Enter fuel litter : 20
# Enter price per litter : 324
# Total fuel cost = 6480.0

# %% [markdown]
# # Practical 19 - Movie Ticket Billing
#
# ## Problem
#
# A family purchases movie tickets.
#
# Ask the user to enter:
#
# - Number of tickets
# - Price per ticket
#
# Display:
# - Total bill
#
# ## Formula
#
# $$\mathrm{Total}=\mathrm{Tickets}\times\mathrm{Price\ Per\ Ticket}$$
#
# ### Pseudocode
#
# ```
# START
# Input number of tickets
# Input price per ticket
# Calculate total bill
# Display total
# END
# ```

# %%
# Write your solution here
ticket = int(input("Enter no of tickets : "))
price = float(input("Enter price per ticket : "))
total_cost = ticket*price
print(f'Total bill = {total_cost}')
# Out:
# Enter no of tickets : 4
# Enter price per ticket : 1200
# Total bill = 4800.0

# %% [markdown]
# # Practical 20 - Safe Division Calculator
#
# ## Problem
#
# Ask the user to enter two numbers.
#
# Calculate the division of the first number by the second.
#
# If the user enters an invalid value or attempts to divide by zero, display an appropriate error message using `try-except`.
#
# ## Formula
#
# $$\mathrm{Result}=\frac{a}{b}$$
#
# ### Pseudocode
#
# ```
# START
# Try
#     Input first number
#     Input second number
#     Calculate division
#     Display result
# Except
#     Display error message
# END
# ```

# %%
# Write your solution here
a = float(input("Enter 1st number  : "))
b = float(input("Enter 2st number  : "))
c = a/b
print(f'Result = {c}')
# Out:
# Enter 1st number  : 54
# Enter 2st number  : 64
# Result = 0.84375
